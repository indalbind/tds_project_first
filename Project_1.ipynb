# %%
import requests
import time
import pandas as pd

# Optional: GitHub token to avoid rate limits
GITHUB_TOKEN = "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"
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"} if GITHUB_TOKEN else {}

# Clean and format company names
def clean_company_name(company):
    if not company:
        return None
    return company.strip().lstrip('@').upper()

# Fetch detailed user information
def fetch_user_details(username):
    url = f"https://api.github.com/users/{username}"
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Error fetching user details for {username}: {response.json()}")
        return None
    return response.json()

# Fetch users in Austin with 100+ followers, dynamically handle pagination
def fetch_users_in_austin():
    url = "https://api.github.com/search/users"
    query = "location:Austin followers:>100"
    users = []
    page = 1

    while True:
        params = {"q": query, "per_page": 100, "page": page}
        response = requests.get(url, headers=HEADERS, params=params)

        if response.status_code != 200:
            print(f"Error: {response.json()}")
            break

        data = response.json().get("items", [])
        if not data:
            break  # No more data, exit the loop

        users.extend(data)
        print(f"Fetched {len(data)} users from page {page}.")
        page += 1  # Move to the next page
        time.sleep(2)  # Be polite to the API

    return users

# Fetch all repositories for a user, dynamically handle pagination
def fetch_repositories(username):
    url = f"https://api.github.com/users/{username}/repos"
    repos = []
    page = 1

    while True:
        params = {"per_page": 100, "page": page}
        response = requests.get(url, headers=HEADERS, params=params)

        if response.status_code != 200:
            print(f"Error fetching repos for {username}: {response.json()}")
            break

        data = response.json()
        if not data:
            break  # No more data, exit the loop

        repos.extend(data)
        print(f"Fetched {len(data)} repos from page {page} for {username}.")
        page += 1  # Move to the next page
        time.sleep(1)  # Be polite to the API

    return repos

# Main function to collect data and export to Excel
def main():
    users_data = []
    repos_data = []

    users = fetch_users_in_austin()
    print(f"Total users fetched: {len(users)}")

    for user in users:
        username = user["login"]
        user_details = fetch_user_details(username)

        if user_details:
            users_data.append({
                "login": user_details["login"],
                "name": user_details.get("name"),
                "company": clean_company_name(user_details.get("company")),
                "location": user_details.get("location"),
                "email": user_details.get("email"),
                "hireable": user_details.get("hireable"),
                "bio": user_details.get("bio"),
                "public_repos": user_details.get("public_repos"),
                "followers": user_details.get("followers"),
                "following": user_details.get("following"),
                "created_at": user_details.get("created_at"),
            })

        print(f"Fetching repositories for {username}...")
        repos = fetch_repositories(username)

        for repo in repos:
            repos_data.append({
                "login": username,
                "full_name": repo["full_name"],
                "created_at": repo["created_at"],
                "stargazers_count": repo["stargazers_count"],
                "watchers_count": repo["watchers_count"],
                "language": repo["language"],
                "has_projects": repo["has_projects"],
                "has_wiki": repo["has_wiki"],
                "license_name": repo["license"]["name"] if repo.get("license") else None
            })

    # Convert data to DataFrames and save to Excel
    users_df = pd.DataFrame(users_data)
    repos_df = pd.DataFrame(repos_data)

    users_df.to_excel("usersall.xlsx", index=False)
    repos_df.to_excel("repositoriesall.xlsx", index=False)

    print("Data saved to users.xlsx and repositories.xlsx")

if __name__ == "__main__":
    main()
# Out:
# Fetched 100 users from page 1.
# Fetched 100 users from page 2.
# Fetched 100 users from page 3.
# Fetched 100 users from page 4.
# Fetched 71 users from page 5.
# Total users fetched: 471
# Fetching repositories for getify...
# Fetched 69 repos from page 1 for getify.
# Fetching repositories for benawad...
# Fetched 100 repos from page 1 for benawad.
# Fetched 100 repos from page 2 for benawad.
# Fetched 54 repos from page 3 for benawad.
# Fetching repositories for steveklabnik...
# Fetched 100 repos from page 1 for steveklabnik.
# Fetched 100 repos from page 2 for steveklabnik.
# Fetched 100 repos from page 3 for steveklabnik.
# Fetched 100 repos from page 4 for steveklabnik.
# Fetched 100 repos from page 5 for steveklabnik.
# Fetched 100 repos from page 6 for steveklabnik.
# Fetched 100 repos from page 7 for steveklabnik.
# Fetched 100 repos from page 8 for steveklabnik.
# Fetched 31 repos from page 9 for steveklabnik.
# Fetching repositories for cloudflare...
# Fetched 100 repos from page 1 for cloudflare.
# Fetched 100 repos from page 2 for cloudflare.
# Fetched 100 repos from page 3 for cloudflare.
# Fetched 100 repos from page 4 for cloudflare.
# Fetched 74 repos from page 5 for cloudflare.
# Fetching repositories for jbogard...
# Fetched 100 repos from page 1 for jbogard.
# Fetched 39 repos from page 2 for jbogard.
# Fetching repositories for EvanBacon...
# Fetched 100 repos from page 1 for EvanBacon.
# Fetched 100 repos from page 2 for EvanBacon.
# Fetched 100 repos from page 3 for EvanBacon.
# Fetched 2 repos from page 4 for EvanBacon.
# Fetching repositories for progrium...
# Fetched 100 repos from page 1 for progrium.
# Fetched 100 repos from page 2 for progrium.
# Fetched 60 repos from page 3 for progrium.
# Fetching repositories for oracle...
# Fetched 100 repos from page 1 for oracle.
# Fetched 100 repos from page 2 for oracle.
# Fetched 84 repos from page 3 for oracle.
# Fetching repositories for GeostatsGuy...
# Fetched 43 repos from page 1 for GeostatsGuy.
# Fetching repositories for benlesh...
# Fetched 100 repos from page 1 for benlesh.
# Fetched 53 repos from page 2 for benlesh.
# Fetching repositories for ContinuumIO...
# Fetched 100 repos from page 1 for ContinuumIO.
# Fetched 82 repos from page 2 for ContinuumIO.
# Fetching repositories for davatron5000...
# Fetched 59 repos from page 1 for davatron5000.
# Fetching repositories for schneems...
# Fetched 100 repos from page 1 for schneems.
# Fetched 100 repos from page 2 for schneems.
# Fetched 100 repos from page 3 for schneems.
# Fetched 100 repos from page 4 for schneems.
# Fetched 80 repos from page 5 for schneems.
# Fetching repositories for wardviaene...
# Fetched 54 repos from page 1 for wardviaene.
# Fetching repositories for mikermcneil...
# Fetched 100 repos from page 1 for mikermcneil.
# Fetched 100 repos from page 2 for mikermcneil.
# Fetched 23 repos from page 3 for mikermcneil.
# Fetching repositories for SlexAxton...
# Fetched 100 repos from page 1 for SlexAxton.
# Fetched 37 repos from page 2 for SlexAxton.
# Fetching repositories for kentonv...
# Fetched 46 repos from page 1 for kentonv.
# Fetching repositories for Dhravya...
# Fetched 81 repos from page 1 for Dhravya.
# Fetching repositories for pfrazee...
# Fetched 100 repos from page 1 for pfrazee.
# Fetched 100 repos from page 2 for pfrazee.
# Fetched 49 repos from page 3 for pfrazee.
# Fetching repositories for dhg...
# Fetched 14 repos from page 1 for dhg.
# Fetching repositories for aweary...
# Fetched 100 repos from page 1 for aweary.
# Fetched 100 repos from page 2 for aweary.
# Fetched 68 repos from page 3 for aweary.
# Fetching repositories for hdm...
# Fetched 30 repos from page 1 for hdm.
# Fetching repositories for mrocklin...
# Fetched 100 repos from page 1 for mrocklin.
# Fetched 100 repos from page 2 for mrocklin.
# Fetched 58 repos from page 3 for mrocklin.
# Fetching repositories for JessicaSachs...
# Fetched 100 repos from page 1 for JessicaSachs.
# Fetched 67 repos from page 2 for JessicaSachs.
# Fetching repositories for codinghemp...
# Fetched 18 repos from page 1 for codinghemp.
# Fetching repositories for srowen...
# Fetched 14 repos from page 1 for srowen.
# Fetching repositories for ruotianluo...
# Fetched 100 repos from page 1 for ruotianluo.
# Fetched 12 repos from page 2 for ruotianluo.
# Fetching repositories for aaronabramov...
# Fetched 100 repos from page 1 for aaronabramov.
# Fetched 32 repos from page 2 for aaronabramov.
# Fetching repositories for pry0cc...
# Fetched 100 repos from page 1 for pry0cc.
# Fetched 11 repos from page 2 for pry0cc.
# Fetching repositories for teoliphant...
# Fetched 33 repos from page 1 for teoliphant.
# Fetching repositories for PaulRashidi...
# Fetched 6 repos from page 1 for PaulRashidi.
# Fetching repositories for brianc...
# Fetched 100 repos from page 1 for brianc.
# Fetched 54 repos from page 2 for brianc.
# Fetching repositories for nathanchapman...
# Fetched 10 repos from page 1 for nathanchapman.
# Fetching repositories for thirtythreeforty...
# Fetched 55 repos from page 1 for thirtythreeforty.
# Fetching repositories for leecalcote...
# Fetched 89 repos from page 1 for leecalcote.
# Fetching repositories for apoelstra...
# Fetched 90 repos from page 1 for apoelstra.
# Fetching repositories for ericclemmons...
# Fetched 100 repos from page 1 for ericclemmons.
# Fetched 100 repos from page 2 for ericclemmons.
# Fetched 10 repos from page 3 for ericclemmons.
# Fetching repositories for jduck...
# Fetched 44 repos from page 1 for jduck.
# Fetching repositories for nateraw...
# Fetched 100 repos from page 1 for nateraw.
# Fetched 22 repos from page 2 for nateraw.
# Fetching repositories for Ir1d...
# Fetched 100 repos from page 1 for Ir1d.
# Fetched 41 repos from page 2 for Ir1d.
# Fetching repositories for wybiral...
# Fetched 97 repos from page 1 for wybiral.
# Fetching repositories for tpolecat...
# Fetched 100 repos from page 1 for tpolecat.
# Fetched 32 repos from page 2 for tpolecat.
# Fetching repositories for billerickson...
# Fetched 91 repos from page 1 for billerickson.
# Fetching repositories for adamstac...
# Fetched 100 repos from page 1 for adamstac.
# Fetched 2 repos from page 2 for adamstac.
# Fetching repositories for a-robinson...
# Fetched 65 repos from page 1 for a-robinson.
# Fetching repositories for hxlnt...
# Fetched 100 repos from page 1 for hxlnt.
# Fetched 29 repos from page 2 for hxlnt.
# Fetching repositories for ACyphus...
# Fetched 45 repos from page 1 for ACyphus.
# Fetching repositories for shergin...
# Fetched 29 repos from page 1 for shergin.
# Fetching repositories for lecoursen...
# Fetched 11 repos from page 1 for lecoursen.
# Fetching repositories for jnewland...
# Fetched 100 repos from page 1 for jnewland.
# Fetched 28 repos from page 2 for jnewland.
# Fetching repositories for devinsays...
# Fetched 51 repos from page 1 for devinsays.
# Fetching repositories for KilledByAPixel...
# Fetched 28 repos from page 1 for KilledByAPixel.
# Fetching repositories for aaronj1335...
# Fetched 100 repos from page 1 for aaronj1335.
# Fetched 24 repos from page 2 for aaronj1335.
# Fetching repositories for MrChromebox...
# Fetched 23 repos from page 1 for MrChromebox.
# Fetching repositories for hone...
# Fetched 100 repos from page 1 for hone.
# Fetched 100 repos from page 2 for hone.
# Fetched 98 repos from page 3 for hone.
# Fetching repositories for caniszczyk...
# Fetched 77 repos from page 1 for caniszczyk.
# Fetching repositories for juliacodes...
# Fetched 23 repos from page 1 for juliacodes.
# Fetching repositories for danielfrg...
# Fetched 100 repos from page 1 for danielfrg.
# Fetched 8 repos from page 2 for danielfrg.
# Fetching repositories for yukezhu...
# Fetched 7 repos from page 1 for yukezhu.
# Fetching repositories for Empact...
# Fetched 100 repos from page 1 for Empact.
# Fetched 100 repos from page 2 for Empact.
# Fetched 22 repos from page 3 for Empact.
# Fetching repositories for bmeck...
# Fetched 100 repos from page 1 for bmeck.
# Fetched 100 repos from page 2 for bmeck.
# Fetched 100 repos from page 3 for bmeck.
# Fetched 53 repos from page 4 for bmeck.
# Fetching repositories for hu-po...
# Fetched 97 repos from page 1 for hu-po.
# Fetching repositories for HarshKapadia2...
# Fetched 93 repos from page 1 for HarshKapadia2.
# Fetching repositories for thinkyhead...
# Fetched 68 repos from page 1 for thinkyhead.
# Fetching repositories for CodyJasonBennett...
# Fetched 75 repos from page 1 for CodyJasonBennett.
# Fetching repositories for daltoniam...
# Fetched 34 repos from page 1 for daltoniam.
# Fetching repositories for jeremydmiller...
# Fetched 26 repos from page 1 for jeremydmiller.
# Fetching repositories for kcharwood...
# Fetched 29 repos from page 1 for kcharwood.
# Fetching repositories for achillean...
# Fetched 15 repos from page 1 for achillean.
# Fetching repositories for SiliconLabs...
# Fetched 100 repos from page 1 for SiliconLabs.
# Fetched 36 repos from page 2 for SiliconLabs.
# Fetching repositories for rachaelshaw...
# Fetched 46 repos from page 1 for rachaelshaw.
# Fetching repositories for mappum...
# Fetched 100 repos from page 1 for mappum.
# Fetched 40 repos from page 2 for mappum.
# Fetching repositories for landley...
# Fetched 6 repos from page 1 for landley.
# Fetching repositories for Embarcadero...
# Fetched 60 repos from page 1 for Embarcadero.
# Fetching repositories for trapexit...
# Fetched 100 repos from page 1 for trapexit.
# Fetched 38 repos from page 2 for trapexit.
# Fetching repositories for kanzure...
# Fetched 100 repos from page 1 for kanzure.
# Fetched 61 repos from page 2 for kanzure.
# Fetching repositories for tswicegood...
# Fetched 100 repos from page 1 for tswicegood.
# Fetched 100 repos from page 2 for tswicegood.
# Fetched 73 repos from page 3 for tswicegood.
# Fetching repositories for darius...
# Fetched 100 repos from page 1 for darius.
# Fetched 45 repos from page 2 for darius.
# Fetching repositories for juntao...
# Fetched 56 repos from page 1 for juntao.
# Fetching repositories for bakpakin...
# Fetched 58 repos from page 1 for bakpakin.
# Fetching repositories for zachriggle...
# Fetched 100 repos from page 1 for zachriggle.
# Fetched 8 repos from page 2 for zachriggle.
# Fetching repositories for catid...
# Fetched 100 repos from page 1 for catid.
# Fetched 27 repos from page 2 for catid.
# Fetching repositories for benthecarman...
# Fetched 100 repos from page 1 for benthecarman.
# Fetched 54 repos from page 2 for benthecarman.
# Fetching repositories for devinus...
# Fetched 100 repos from page 1 for devinus.
# Fetched 100 repos from page 2 for devinus.
# Fetched 11 repos from page 3 for devinus.
# Fetching repositories for titusfortner...
# Fetched 99 repos from page 1 for titusfortner.
# Fetching repositories for prograhammer...
# Fetched 42 repos from page 1 for prograhammer.
# Fetching repositories for pedramamini...
# Fetched 43 repos from page 1 for pedramamini.
# Fetching repositories for dan...
# Fetched 7 repos from page 1 for dan.
# Fetching repositories for pragmaticivan...
# Fetched 100 repos from page 1 for pragmaticivan.
# Fetched 75 repos from page 2 for pragmaticivan.
# Fetching repositories for kevinbluer...
# Fetched 100 repos from page 1 for kevinbluer.
# Fetched 100 repos from page 2 for kevinbluer.
# Fetched 8 repos from page 3 for kevinbluer.
# Fetching repositories for opencomputeproject...
# Fetched 100 repos from page 1 for opencomputeproject.
# Fetched 22 repos from page 2 for opencomputeproject.
# Fetching repositories for StephenMayeux...
# Fetched 100 repos from page 1 for StephenMayeux.
# Fetched 100 repos from page 2 for StephenMayeux.
# Fetched 62 repos from page 3 for StephenMayeux.
# Fetching repositories for thoughtpolice...
# Fetched 100 repos from page 1 for thoughtpolice.
# Fetched 18 repos from page 2 for thoughtpolice.
# Fetching repositories for brandonprry...
# Fetched 54 repos from page 1 for brandonprry.
# Fetching repositories for chriskacerguis...
# Fetched 14 repos from page 1 for chriskacerguis.
# Fetching repositories for thobbs...
# Fetched 48 repos from page 1 for thobbs.
# Fetching repositories for jhaynie...
# Fetched 100 repos from page 1 for jhaynie.
# Fetched 15 repos from page 2 for jhaynie.
# Fetching repositories for mateodelnorte...
# Fetched 100 repos from page 1 for mateodelnorte.
# Fetched 26 repos from page 2 for mateodelnorte.
# Fetching repositories for RadeonOpenCompute...
# Fetched 4 repos from page 1 for RadeonOpenCompute.
# Fetching repositories for cowboyd...
# Fetched 100 repos from page 1 for cowboyd.
# Fetched 100 repos from page 2 for cowboyd.
# Fetched 70 repos from page 3 for cowboyd.
# Fetching repositories for praetorian-inc...
# Fetched 59 repos from page 1 for praetorian-inc.
# Fetching repositories for brianairb...
# Fetched 7 repos from page 1 for brianairb.
# Fetching repositories for jcustenborder...
# Fetched 100 repos from page 1 for jcustenborder.
# Fetched 81 repos from page 2 for jcustenborder.
# Fetching repositories for hammadmobin...
# Fetched 56 repos from page 1 for hammadmobin.
# Fetching repositories for second-state...
# Fetched 100 repos from page 1 for second-state.
# Fetched 100 repos from page 2 for second-state.
# Fetched 71 repos from page 3 for second-state.
# Fetching repositories for dtao...
# Fetched 100 repos from page 1 for dtao.
# Fetched 83 repos from page 2 for dtao.
# Fetching repositories for johntfoster...
# Fetched 89 repos from page 1 for johntfoster.
# Fetching repositories for joshblack...
# Fetched 100 repos from page 1 for joshblack.
# Fetched 100 repos from page 2 for joshblack.
# Fetched 14 repos from page 3 for joshblack.
# Fetching repositories for zaradarz...
# Fetched 5 repos from page 1 for zaradarz.
# Fetching repositories for hassox...
# Fetched 100 repos from page 1 for hassox.
# Fetched 56 repos from page 2 for hassox.
# Fetching repositories for chadmcrowell...
# Fetched 100 repos from page 1 for chadmcrowell.
# Fetched 100 repos from page 2 for chadmcrowell.
# Fetched 26 repos from page 3 for chadmcrowell.
# Fetching repositories for alicemaz...
# Fetched 8 repos from page 1 for alicemaz.
# Fetching repositories for rFlex...
# Fetched 31 repos from page 1 for rFlex.
# Fetching repositories for sophshep...
# Fetched 17 repos from page 1 for sophshep.
# Fetching repositories for exodusintel...
# Fetched 7 repos from page 1 for exodusintel.
# Fetching repositories for stella3d...
# Fetched 54 repos from page 1 for stella3d.
# Fetching repositories for jjasghar...
# Fetched 100 repos from page 1 for jjasghar.
# Fetched 99 repos from page 2 for jjasghar.
# Fetching repositories for zsylvester...
# Fetched 21 repos from page 1 for zsylvester.
# Fetching repositories for xpl...
# Fetched 32 repos from page 1 for xpl.
# Fetching repositories for dustinkirkland...
# Fetched 54 repos from page 1 for dustinkirkland.
# Fetching repositories for reaperhulk...
# Fetched 100 repos from page 1 for reaperhulk.
# Fetched 28 repos from page 2 for reaperhulk.
# Fetching repositories for azuresphere7...
# Fetched 100 repos from page 1 for azuresphere7.
# Fetched 2 repos from page 2 for azuresphere7.
# Fetching repositories for gilbert...
# Fetched 100 repos from page 1 for gilbert.
# Fetched 92 repos from page 2 for gilbert.
# Fetching repositories for philkr...
# Fetched 16 repos from page 1 for philkr.
# Fetching repositories for irlnathan...
# Fetched 100 repos from page 1 for irlnathan.
# Fetched 15 repos from page 2 for irlnathan.
# Fetching repositories for jcran...
# Fetched 4 repos from page 1 for jcran.
# Fetching repositories for DavidAJohnston...
# Fetched 100 repos from page 1 for DavidAJohnston.
# Fetched 29 repos from page 2 for DavidAJohnston.
# Fetching repositories for birdsarah...
# Fetched 57 repos from page 1 for birdsarah.
# Fetching repositories for nodebotanist...
# Fetched 100 repos from page 1 for nodebotanist.
# Fetched 100 repos from page 2 for nodebotanist.
# Fetched 83 repos from page 3 for nodebotanist.
# Fetching repositories for shortstack...
# Fetched 36 repos from page 1 for shortstack.
# Fetching repositories for scarolan...
# Fetched 28 repos from page 1 for scarolan.
# Fetching repositories for BDHU...
# Fetched 24 repos from page 1 for BDHU.
# Fetching repositories for alvaromontoro...
# Fetched 40 repos from page 1 for alvaromontoro.
# Fetching repositories for jalapic...
# Fetched 94 repos from page 1 for jalapic.
# Fetching repositories for joshtronic...
# Fetched 68 repos from page 1 for joshtronic.
# Fetching repositories for BusterNeece...
# Fetched 8 repos from page 1 for BusterNeece.
# Fetching repositories for mrflip...
# Fetched 100 repos from page 1 for mrflip.
# Fetched 44 repos from page 2 for mrflip.
# Fetching repositories for ryanhlewis...
# Fetched 58 repos from page 1 for ryanhlewis.
# Fetching repositories for Arinerron...
# Fetched 100 repos from page 1 for Arinerron.
# Fetched 7 repos from page 2 for Arinerron.
# Fetching repositories for jonthegeek...
# Fetched 100 repos from page 1 for jonthegeek.
# Fetched 58 repos from page 2 for jonthegeek.
# Fetching repositories for DavidStinson...
# Fetched 100 repos from page 1 for DavidStinson.
# Fetched 22 repos from page 2 for DavidStinson.
# Fetching repositories for nklayman...
# Fetched 47 repos from page 1 for nklayman.
# Fetching repositories for yifanjiang19...
# Fetched 34 repos from page 1 for yifanjiang19.
# Fetching repositories for syedhali...
# Fetched 42 repos from page 1 for syedhali.
# Fetching repositories for luwes...
# Fetched 69 repos from page 1 for luwes.
# Fetching repositories for zobront...
# Fetched 56 repos from page 1 for zobront.
# Fetching repositories for akutz...
# Fetched 100 repos from page 1 for akutz.
# Fetched 96 repos from page 2 for akutz.
# Fetching repositories for dbaldwin...
# Fetched 100 repos from page 1 for dbaldwin.
# Fetched 4 repos from page 2 for dbaldwin.
# Fetching repositories for evanlucas...
# Fetched 100 repos from page 1 for evanlucas.
# Fetched 100 repos from page 2 for evanlucas.
# Fetched 83 repos from page 3 for evanlucas.
# Fetching repositories for holtskinner...
# Fetched 66 repos from page 1 for holtskinner.
# Fetching repositories for wickett...
# Fetched 66 repos from page 1 for wickett.
# Fetching repositories for wpengine...
# Fetched 43 repos from page 1 for wpengine.
# Fetching repositories for gnomeontherun...
# Fetched 100 repos from page 1 for gnomeontherun.
# Fetched 56 repos from page 2 for gnomeontherun.
# Fetching repositories for mdbartos...
# Fetched 34 repos from page 1 for mdbartos.
# Fetching repositories for ospencer...
# Fetched 47 repos from page 1 for ospencer.
# Fetching repositories for paulczar...
# Fetched 100 repos from page 1 for paulczar.
# Fetched 100 repos from page 2 for paulczar.
# Fetched 100 repos from page 3 for paulczar.
# Fetched 81 repos from page 4 for paulczar.
# Fetching repositories for sanity...
# Fetched 58 repos from page 1 for sanity.
# Fetching repositories for particlebanana...
# Fetched 72 repos from page 1 for particlebanana.
# Fetching repositories for sahin...
# Fetched 40 repos from page 1 for sahin.
# Fetching repositories for markmarkoh...
# Fetched 49 repos from page 1 for markmarkoh.
# Fetching repositories for sebersole...
# Fetched 59 repos from page 1 for sebersole.
# Fetching repositories for jdorn...
# Fetched 22 repos from page 1 for jdorn.
# Fetching repositories for jbednar...
# Fetched 25 repos from page 1 for jbednar.
# Fetching repositories for msarahan...
# Fetched 100 repos from page 1 for msarahan.
# Fetched 100 repos from page 2 for msarahan.
# Fetched 100 repos from page 3 for msarahan.
# Fetched 53 repos from page 4 for msarahan.
# Fetching repositories for benbrown...
# Fetched 29 repos from page 1 for benbrown.
# Fetching repositories for fredemmott...
# Fetched 100 repos from page 1 for fredemmott.
# Fetched 50 repos from page 2 for fredemmott.
# Fetching repositories for bradgarropy...
# Fetched 100 repos from page 1 for bradgarropy.
# Fetched 33 repos from page 2 for bradgarropy.
# Fetching repositories for nicolaka...
# Fetched 100 repos from page 1 for nicolaka.
# Fetched 6 repos from page 2 for nicolaka.
# Fetching repositories for drusellers...
# Fetched 77 repos from page 1 for drusellers.
# Fetching repositories for brad-decker...
# Fetched 43 repos from page 1 for brad-decker.
# Fetching repositories for jbellis...
# Fetched 66 repos from page 1 for jbellis.
# Fetching repositories for JacobMGEvans...
# Fetched 76 repos from page 1 for JacobMGEvans.
# Fetching repositories for TrentWalton...
# Fetched 3 repos from page 1 for TrentWalton.
# Fetching repositories for splittingred...
# Fetched 91 repos from page 1 for splittingred.
# Fetching repositories for jiaaro...
# Fetched 61 repos from page 1 for jiaaro.
# Fetching repositories for jeffreybiles...
# Fetched 100 repos from page 1 for jeffreybiles.
# Fetched 24 repos from page 2 for jeffreybiles.
# Fetching repositories for epixoip...
# Fetched 19 repos from page 1 for epixoip.
# Fetching repositories for sh1mmer...
# Fetched 39 repos from page 1 for sh1mmer.
# Fetching repositories for handcraftsman...
# Fetched 30 repos from page 1 for handcraftsman.
# Fetching repositories for gfontenot...
# Fetched 43 repos from page 1 for gfontenot.
# Fetching repositories for JoshuaWise...
# Fetched 40 repos from page 1 for JoshuaWise.
# Fetching repositories for JFrankfurt...
# Fetched 94 repos from page 1 for JFrankfurt.
# Fetching repositories for aterrel...
# Fetched 78 repos from page 1 for aterrel.
# Fetching repositories for allada...
# Fetched 48 repos from page 1 for allada.
# Fetching repositories for bigcommerce...
# Fetched 100 repos from page 1 for bigcommerce.
# Fetched 100 repos from page 2 for bigcommerce.
# Fetched 64 repos from page 3 for bigcommerce.
# Fetching repositories for peteanderson80...
# Fetched 8 repos from page 1 for peteanderson80.
# Fetching repositories for jamesbornholt...
# Fetched 45 repos from page 1 for jamesbornholt.
# Fetching repositories for iMerica...
# Fetched 100 repos from page 1 for iMerica.
# Fetched 88 repos from page 2 for iMerica.
# Fetching repositories for jpotts...
# Fetched 68 repos from page 1 for jpotts.
# Fetching repositories for karthequian...
# Fetched 70 repos from page 1 for karthequian.
# Fetching repositories for sfomel...
# Fetched 13 repos from page 1 for sfomel.
# Fetching repositories for bradyz...
# Fetched 30 repos from page 1 for bradyz.
# Fetching repositories for MasonEgger...
# Fetched 35 repos from page 1 for MasonEgger.
# Fetching repositories for rfdickerson...
# Fetched 100 repos from page 1 for rfdickerson.
# Fetched 78 repos from page 2 for rfdickerson.
# Fetching repositories for jenperson...
# Fetched 35 repos from page 1 for jenperson.
# Fetching repositories for kalefranz...
# Fetched 94 repos from page 1 for kalefranz.
# Fetching repositories for realityexpander...
# Fetched 100 repos from page 1 for realityexpander.
# Fetched 100 repos from page 2 for realityexpander.
# Fetched 100 repos from page 3 for realityexpander.
# Fetched 100 repos from page 4 for realityexpander.
# Fetched 69 repos from page 5 for realityexpander.
# Fetching repositories for jeffreypalermo...
# Fetched 33 repos from page 1 for jeffreypalermo.
# Fetching repositories for jeffamstutz...
# Fetched 86 repos from page 1 for jeffamstutz.
# Fetching repositories for magento-engcom-team...
# Fetched 1 repos from page 1 for magento-engcom-team.
# Fetching repositories for AdamBrodzinski...
# Fetched 49 repos from page 1 for AdamBrodzinski.
# Fetching repositories for okyeron...
# Fetched 100 repos from page 1 for okyeron.
# Fetching repositories for Just-Moh-it...
# Fetched 52 repos from page 1 for Just-Moh-it.
# Fetching repositories for koltyakov...
# Fetched 50 repos from page 1 for koltyakov.
# Fetching repositories for wbobeirne...
# Fetched 100 repos from page 1 for wbobeirne.
# Fetched 55 repos from page 2 for wbobeirne.
# Fetching repositories for ArturoNereu...
# Fetched 33 repos from page 1 for ArturoNereu.
# Fetching repositories for jasonappah...
# Fetched 84 repos from page 1 for jasonappah.
# Fetching repositories for devrim...
# Fetched 28 repos from page 1 for devrim.
# Fetching repositories for baronfel...
# Fetched 100 repos from page 1 for baronfel.
# Fetched 100 repos from page 2 for baronfel.
# Fetched 65 repos from page 3 for baronfel.
# Fetching repositories for ChrisMissal...
# Fetched 100 repos from page 1 for ChrisMissal.
# Fetched 89 repos from page 2 for ChrisMissal.
# Fetching repositories for giannisdaras...
# Fetched 94 repos from page 1 for giannisdaras.
# Fetching repositories for sgress454...
# Fetched 63 repos from page 1 for sgress454.
# Fetching repositories for jasonppy...
# Fetched 16 repos from page 1 for jasonppy.
# Fetching repositories for FellowTraveler...
# Fetched 100 repos from page 1 for FellowTraveler.
# Fetched 100 repos from page 2 for FellowTraveler.
# Fetched 100 repos from page 3 for FellowTraveler.
# Fetched 100 repos from page 4 for FellowTraveler.
# Fetched 100 repos from page 5 for FellowTraveler.
# Fetched 100 repos from page 6 for FellowTraveler.
# Fetched 34 repos from page 7 for FellowTraveler.
# Fetching repositories for sylvanc...
# Fetched 14 repos from page 1 for sylvanc.
# Fetching repositories for alex-miller-0...
# Fetched 56 repos from page 1 for alex-miller-0.
# Fetching repositories for manton...
# Fetched 25 repos from page 1 for manton.
# Fetching repositories for bgentry...
# Fetched 100 repos from page 1 for bgentry.
# Fetched 100 repos from page 2 for bgentry.
# Fetched 17 repos from page 3 for bgentry.
# Fetching repositories for smashism...
# Fetched 54 repos from page 1 for smashism.
# Fetching repositories for chriswahl...
# Fetched 1 repos from page 1 for chriswahl.
# Fetching repositories for Noah-Kennedy...
# Fetched 100 repos from page 1 for Noah-Kennedy.
# Fetched 33 repos from page 2 for Noah-Kennedy.
# Fetching repositories for sklam...
# Fetched 69 repos from page 1 for sklam.
# Fetching repositories for DataDaimon...
# Fetched 15 repos from page 1 for DataDaimon.
# Fetching repositories for koverholt...
# Fetched 71 repos from page 1 for koverholt.
# Fetching repositories for dokun1...
# Fetched 100 repos from page 1 for dokun1.
# Fetched 21 repos from page 2 for dokun1.
# Fetching repositories for drewcrawford...
# Fetched 71 repos from page 1 for drewcrawford.
# Fetching repositories for beiatrix...
# Fetched 22 repos from page 1 for beiatrix.
# Fetching repositories for PaulBratslavsky...
# Fetched 100 repos from page 1 for PaulBratslavsky.
# Fetched 100 repos from page 2 for PaulBratslavsky.
# Fetched 100 repos from page 3 for PaulBratslavsky.
# Fetched 100 repos from page 4 for PaulBratslavsky.
# Fetched 100 repos from page 5 for PaulBratslavsky.
# Fetched 71 repos from page 6 for PaulBratslavsky.
# Fetching repositories for robertsosinski...
# Fetched 33 repos from page 1 for robertsosinski.
# Fetching repositories for dlo...
# Fetched 100 repos from page 1 for dlo.
# Fetched 17 repos from page 2 for dlo.
# Fetching repositories for DrewML...
# Fetched 100 repos from page 1 for DrewML.
# Fetched 3 repos from page 2 for DrewML.
# Fetching repositories for sailpoint-oss...
# Fetched 79 repos from page 1 for sailpoint-oss.
# Fetching repositories for brundonsmith...
# Fetched 63 repos from page 1 for brundonsmith.
# Fetching repositories for techthoughts2...
# Fetched 33 repos from page 1 for techthoughts2.
# Fetching repositories for ZeroMemes...
# Fetched 24 repos from page 1 for ZeroMemes.
# Fetching repositories for jasonbaldridge...
# Fetched 16 repos from page 1 for jasonbaldridge.
# Fetching repositories for mrjasonweaver...
# Fetched 44 repos from page 1 for mrjasonweaver.
# Fetching repositories for dpmex4527...
# Fetched 9 repos from page 1 for dpmex4527.
# Fetching repositories for oracle-terraform-modules...
# Fetched 28 repos from page 1 for oracle-terraform-modules.
# Fetching repositories for treyhuffine...
# Fetched 100 repos from page 1 for treyhuffine.
# Fetched 29 repos from page 2 for treyhuffine.
# Fetching repositories for OR13...
# Fetched 100 repos from page 1 for OR13.
# Fetched 100 repos from page 2 for OR13.
# Fetched 83 repos from page 3 for OR13.
# Fetching repositories for DDRBoxman...
# Fetched 100 repos from page 1 for DDRBoxman.
# Fetched 100 repos from page 2 for DDRBoxman.
# Fetched 42 repos from page 3 for DDRBoxman.
# Fetching repositories for viritaromero...
# Fetched 45 repos from page 1 for viritaromero.
# Fetching repositories for vijay03...
# Fetched 18 repos from page 1 for vijay03.
# Fetching repositories for mitchspano...
# Fetched 15 repos from page 1 for mitchspano.
# Fetching repositories for leoroese...
# Fetched 26 repos from page 1 for leoroese.
# Fetching repositories for mcroydon...
# Fetched 55 repos from page 1 for mcroydon.
# Fetching repositories for tzlaine...
# Fetched 69 repos from page 1 for tzlaine.
# Fetching repositories for JostineHo...
# Fetched 17 repos from page 1 for JostineHo.
# Fetching repositories for nazmulidris...
# Fetched 100 repos from page 1 for nazmulidris.
# Fetched 22 repos from page 2 for nazmulidris.
# Fetching repositories for mahanta-mayur...
# Fetched 31 repos from page 1 for mahanta-mayur.
# Fetching repositories for rfxn...
# Fetched 45 repos from page 1 for rfxn.
# Fetching repositories for leachim6...
# Fetched 29 repos from page 1 for leachim6.
# Fetching repositories for rphillips...
# Fetched 100 repos from page 1 for rphillips.
# Fetched 90 repos from page 2 for rphillips.
# Fetching repositories for robswc...
# Fetched 48 repos from page 1 for robswc.
# Fetching repositories for sdnts...
# Fetched 24 repos from page 1 for sdnts.
# Fetching repositories for mtscout6...
# Fetched 100 repos from page 1 for mtscout6.
# Fetched 42 repos from page 2 for mtscout6.
# Fetching repositories for anibalsolon...
# Fetched 100 repos from page 1 for anibalsolon.
# Fetched 80 repos from page 2 for anibalsolon.
# Fetching repositories for mayoff...
# Fetched 100 repos from page 1 for mayoff.
# Fetched 49 repos from page 2 for mayoff.
# Fetching repositories for teleject...
# Fetched 84 repos from page 1 for teleject.
# Fetching repositories for ftarlaci...
# Fetched 72 repos from page 1 for ftarlaci.
# Fetching repositories for msjenkins-r7...
# Fetching repositories for atxsinn3r...
# Fetched 10 repos from page 1 for atxsinn3r.
# Fetching repositories for linyiru...
# Fetched 57 repos from page 1 for linyiru.
# Fetching repositories for austintoddj...
# Fetched 33 repos from page 1 for austintoddj.
# Fetching repositories for mcg1969...
# Fetched 63 repos from page 1 for mcg1969.
# Fetching repositories for todb...
# Fetched 26 repos from page 1 for todb.
# Fetching repositories for KensoDev...
# Fetched 100 repos from page 1 for KensoDev.
# Fetched 100 repos from page 2 for KensoDev.
# Fetched 33 repos from page 3 for KensoDev.
# Fetching repositories for hartator...
# Fetched 89 repos from page 1 for hartator.
# Fetching repositories for ericlaw1979...
# Fetched 80 repos from page 1 for ericlaw1979.
# Fetching repositories for pifantastic...
# Fetched 100 repos from page 1 for pifantastic.
# Fetched 2 repos from page 2 for pifantastic.
# Fetching repositories for sagivo...
# Fetched 100 repos from page 1 for sagivo.
# Fetched 26 repos from page 2 for sagivo.
# Fetching repositories for loweryaustin...
# Fetched 10 repos from page 1 for loweryaustin.
# Fetching repositories for mattdeboard...
# Fetched 100 repos from page 1 for mattdeboard.
# Fetched 4 repos from page 2 for mattdeboard.
# Fetching repositories for Robdel12...
# Fetched 100 repos from page 1 for Robdel12.
# Fetched 37 repos from page 2 for Robdel12.
# Fetching repositories for acmacalister...
# Fetched 41 repos from page 1 for acmacalister.
# Fetching repositories for MalwareArchaeology...
# Fetched 2 repos from page 1 for MalwareArchaeology.
# Fetching repositories for hari-sikchi...
# Fetched 80 repos from page 1 for hari-sikchi.
# Fetching repositories for omniedgeio...
# Fetched 24 repos from page 1 for omniedgeio.
# Fetching repositories for Jmeyer1292...
# Fetched 77 repos from page 1 for Jmeyer1292.
# Fetching repositories for keppel...
# Fetched 40 repos from page 1 for keppel.
# Fetching repositories for jrf0110...
# Fetched 100 repos from page 1 for jrf0110.
# Fetched 100 repos from page 2 for jrf0110.
# Fetched 2 repos from page 3 for jrf0110.
# Fetching repositories for 1000hz...
# Fetched 41 repos from page 1 for 1000hz.
# Fetching repositories for adamchalmers...
# Fetched 100 repos from page 1 for adamchalmers.
# Fetched 53 repos from page 2 for adamchalmers.
# Fetching repositories for coreyward...
# Fetched 84 repos from page 1 for coreyward.
# Fetching repositories for mikebrow...
# Fetched 69 repos from page 1 for mikebrow.
# Fetching repositories for chipsenkbeil...
# Fetched 94 repos from page 1 for chipsenkbeil.
# Fetching repositories for thebigredgeek...
# Fetched 100 repos from page 1 for thebigredgeek.
# Fetched 13 repos from page 2 for thebigredgeek.
# Fetching repositories for mediwareinc...
# Fetched 18 repos from page 1 for mediwareinc.
# Fetching repositories for gbin...
# Fetched 52 repos from page 1 for gbin.
# Fetching repositories for BleepLabs...
# Fetched 51 repos from page 1 for BleepLabs.
# Fetching repositories for joonas...
# Fetched 100 repos from page 1 for joonas.
# Fetched 32 repos from page 2 for joonas.
# Fetching repositories for sinn3r...
# Fetching repositories for GitBoSun...
# Fetched 13 repos from page 1 for GitBoSun.
# Fetching repositories for ammario...
# Fetched 56 repos from page 1 for ammario.
# Fetching repositories for newswim...
# Fetched 100 repos from page 1 for newswim.
# Fetched 100 repos from page 2 for newswim.
# Fetched 100 repos from page 3 for newswim.
# Fetched 46 repos from page 4 for newswim.
# Fetching repositories for artjmaria...
# Fetched 49 repos from page 1 for artjmaria.
# Fetching repositories for Anaconda-Platform...
# Fetching repositories for shoenig...
# Fetched 87 repos from page 1 for shoenig.
# Fetching repositories for safijari...
# Fetched 100 repos from page 1 for safijari.
# Fetched 23 repos from page 2 for safijari.
# Fetching repositories for yuehaowang...
# Fetched 26 repos from page 1 for yuehaowang.
# Fetching repositories for jmswisher...
# Fetched 16 repos from page 1 for jmswisher.
# Fetching repositories for atlassian-labs...
# Fetched 53 repos from page 1 for atlassian-labs.
# Fetching repositories for blanu...
# Fetched 100 repos from page 1 for blanu.
# Fetched 26 repos from page 2 for blanu.
# Fetching repositories for ccrama...
# Fetched 46 repos from page 1 for ccrama.
# Fetching repositories for nertzy...
# Fetched 100 repos from page 1 for nertzy.
# Fetched 24 repos from page 2 for nertzy.
# Fetching repositories for bentruyman...
# Fetched 29 repos from page 1 for bentruyman.
# Fetching repositories for ryanirelan...
# Fetched 56 repos from page 1 for ryanirelan.
# Fetching repositories for ramhiser...
# Fetched 51 repos from page 1 for ramhiser.
# Fetching repositories for thezdi...
# Fetched 8 repos from page 1 for thezdi.
# Fetching repositories for cdgriffith...
# Fetched 41 repos from page 1 for cdgriffith.
# Fetching repositories for bsatrom...
# Fetched 100 repos from page 1 for bsatrom.
# Fetched 58 repos from page 2 for bsatrom.
# Fetching repositories for ilanschnell...
# Fetched 39 repos from page 1 for ilanschnell.
# Fetching repositories for arohner...
# Fetched 90 repos from page 1 for arohner.
# Fetching repositories for josefnpat...
# Fetched 100 repos from page 1 for josefnpat.
# Fetched 35 repos from page 2 for josefnpat.
# Fetching repositories for jack-oquin...
# Fetched 22 repos from page 1 for jack-oquin.
# Fetching repositories for windelicato...
# Fetched 12 repos from page 1 for windelicato.
# Fetching repositories for theori-io...
# Fetched 33 repos from page 1 for theori-io.
# Fetching repositories for rholder...
# Fetched 45 repos from page 1 for rholder.
# Fetching repositories for shili2017...
# Fetched 11 repos from page 1 for shili2017.
# Fetching repositories for brandonrosage...
# Fetched 6 repos from page 1 for brandonrosage.
# Fetching repositories for AshM10...
# Fetched 49 repos from page 1 for AshM10.
# Fetching repositories for robwierzbowski...
# Fetched 13 repos from page 1 for robwierzbowski.
# Fetching repositories for enthought...
# Fetched 100 repos from page 1 for enthought.
# Fetched 53 repos from page 2 for enthought.
# Fetching repositories for bowdenk7...
# Fetched 90 repos from page 1 for bowdenk7.
# Fetching repositories for derekargueta...
# Fetched 48 repos from page 1 for derekargueta.
# Fetching repositories for bcook-r7...
# Fetched 4 repos from page 1 for bcook-r7.
# Fetching repositories for witoff...
# Fetched 77 repos from page 1 for witoff.
# Fetching repositories for RobertLRead...
# Fetched 24 repos from page 1 for RobertLRead.
# Fetching repositories for lewing...
# Fetched 42 repos from page 1 for lewing.
# Fetching repositories for EttusResearch...
# Fetched 23 repos from page 1 for EttusResearch.
# Fetching repositories for jshcrowthe...
# Fetched 62 repos from page 1 for jshcrowthe.
# Fetching repositories for ccraddock...
# Fetched 92 repos from page 1 for ccraddock.
# Fetching repositories for damon...
# Fetched 16 repos from page 1 for damon.
# Fetching repositories for mistermoe...
# Fetched 51 repos from page 1 for mistermoe.
# Fetching repositories for alexhuth...
# Fetched 25 repos from page 1 for alexhuth.
# Fetching repositories for MontealegreLuis...
# Fetched 73 repos from page 1 for MontealegreLuis.
# Fetching repositories for grahamwaters...
# Fetched 100 repos from page 1 for grahamwaters.
# Fetched 25 repos from page 2 for grahamwaters.
# Fetching repositories for gully...
# Fetched 100 repos from page 1 for gully.
# Fetched 16 repos from page 2 for gully.
# Fetching repositories for kernelsmith...
# Fetched 67 repos from page 1 for kernelsmith.
# Fetching repositories for moagrius...
# Fetched 41 repos from page 1 for moagrius.
# Fetching repositories for hellobrian...
# Fetched 100 repos from page 1 for hellobrian.
# Fetched 37 repos from page 2 for hellobrian.
# Fetching repositories for SaltyQuetzals...
# Fetched 31 repos from page 1 for SaltyQuetzals.
# Fetching repositories for Xibanya...
# Fetched 25 repos from page 1 for Xibanya.
# Fetching repositories for jakecraige...
# Fetched 97 repos from page 1 for jakecraige.
# Fetching repositories for joahg...
# Fetched 6 repos from page 1 for joahg.
# Fetching repositories for baalexander...
# Fetched 3 repos from page 1 for baalexander.
# Fetching repositories for emcho...
# Fetched 23 repos from page 1 for emcho.
# Fetching repositories for shellcromancer...
# Fetched 25 repos from page 1 for shellcromancer.
# Fetching repositories for daniel-nagy...
# Fetched 29 repos from page 1 for daniel-nagy.
# Fetching repositories for AustinKelsay...
# Fetched 100 repos from page 1 for AustinKelsay.
# Fetched 100 repos from page 2 for AustinKelsay.
# Fetched 38 repos from page 3 for AustinKelsay.
# Fetching repositories for sunny-g...
# Fetched 100 repos from page 1 for sunny-g.
# Fetched 100 repos from page 2 for sunny-g.
# Fetched 26 repos from page 3 for sunny-g.
# Fetching repositories for heyjaywilson...
# Fetched 74 repos from page 1 for heyjaywilson.
# Fetching repositories for coadler...
# Fetched 53 repos from page 1 for coadler.
# Fetching repositories for nectariferous...
# Fetched 70 repos from page 1 for nectariferous.
# Fetching repositories for amberleyromo...
# Fetched 46 repos from page 1 for amberleyromo.
# Fetching repositories for jedwards1211...
# Fetched 100 repos from page 1 for jedwards1211.
# Fetched 100 repos from page 2 for jedwards1211.
# Fetched 100 repos from page 3 for jedwards1211.
# Fetched 4 repos from page 4 for jedwards1211.
# Fetching repositories for koeninger...
# Fetched 73 repos from page 1 for koeninger.
# Fetching repositories for ajbozarth...
# Fetched 35 repos from page 1 for ajbozarth.
# Fetching repositories for OneCricketeer...
# Fetched 52 repos from page 1 for OneCricketeer.
# Fetching repositories for cloudburst...
# Fetched 10 repos from page 1 for cloudburst.
# Fetching repositories for UT-Austin-RPL...
# Fetched 33 repos from page 1 for UT-Austin-RPL.
# Fetching repositories for gpdowning...
# Fetched 1 repos from page 1 for gpdowning.
# Fetching repositories for DavidWittman...
# Fetched 100 repos from page 1 for DavidWittman.
# Fetched 44 repos from page 2 for DavidWittman.
# Fetching repositories for cmdruid...
# Fetched 70 repos from page 1 for cmdruid.
# Fetching repositories for dknecht...
# Fetched 3 repos from page 1 for dknecht.
# Fetching repositories for GluuFederation...
# Fetched 100 repos from page 1 for GluuFederation.
# Fetched 34 repos from page 2 for GluuFederation.
# Fetching repositories for mikesurowiec...
# Fetched 17 repos from page 1 for mikesurowiec.
# Fetching repositories for WillAbides...
# Fetched 100 repos from page 1 for WillAbides.
# Fetched 35 repos from page 2 for WillAbides.
# Fetching repositories for AutoMapper...
# Fetched 11 repos from page 1 for AutoMapper.
# Fetching repositories for ericyd...
# Fetched 55 repos from page 1 for ericyd.
# Fetching repositories for jimbojsb...
# Fetched 99 repos from page 1 for jimbojsb.
# Fetching repositories for lovemecomputer...
# Fetched 51 repos from page 1 for lovemecomputer.
# Fetching repositories for camilonova...
# Fetched 88 repos from page 1 for camilonova.
# Fetching repositories for joshknowles...
# Fetched 14 repos from page 1 for joshknowles.
# Fetching repositories for ianjennings...
# Fetched 100 repos from page 1 for ianjennings.
# Fetched 100 repos from page 2 for ianjennings.
# Fetched 18 repos from page 3 for ianjennings.
# Fetching repositories for rauhryan...
# Fetched 92 repos from page 1 for rauhryan.
# Fetching repositories for mpenning...
# Fetched 51 repos from page 1 for mpenning.
# Fetching repositories for kiat...
# Fetched 100 repos from page 1 for kiat.
# Fetched 24 repos from page 2 for kiat.
# Fetching repositories for MichaelDesantis...
# Fetched 19 repos from page 1 for MichaelDesantis.
# Fetching repositories for h3h...
# Fetched 59 repos from page 1 for h3h.
# Fetching repositories for Xandromus...
# Fetched 22 repos from page 1 for Xandromus.
# Fetching repositories for ecapuano...
# Fetched 42 repos from page 1 for ecapuano.
# Fetching repositories for jtraglia...
# Fetched 57 repos from page 1 for jtraglia.
# Fetching repositories for pfuri...
# Fetched 17 repos from page 1 for pfuri.
# Fetching repositories for 0xwilliamli...
# Fetched 30 repos from page 1 for 0xwilliamli.
# Fetching repositories for Rav4s...
# Fetched 31 repos from page 1 for Rav4s.
# Fetching repositories for unwiredben...
# Fetched 99 repos from page 1 for unwiredben.
# Fetching repositories for mflaxman...
# Fetched 52 repos from page 1 for mflaxman.
# Fetching repositories for aporat...
# Fetched 29 repos from page 1 for aporat.
# Fetching repositories for samkap...
# Fetched 50 repos from page 1 for samkap.
# Fetching repositories for preetapan...
# Fetched 7 repos from page 1 for preetapan.
# Fetching repositories for grgcombs...
# Fetched 86 repos from page 1 for grgcombs.
# Fetching repositories for stevehanson...
# Fetched 79 repos from page 1 for stevehanson.
# Fetching repositories for prestonsn...
# Fetched 33 repos from page 1 for prestonsn.
# Fetching repositories for kraftbj...
# Fetched 92 repos from page 1 for kraftbj.
# Fetching repositories for itsjustkevin...
# Fetched 32 repos from page 1 for itsjustkevin.
# Fetching repositories for tlivings...
# Fetched 73 repos from page 1 for tlivings.
# Fetching repositories for jjn1056...
# Fetched 100 repos from page 1 for jjn1056.
# Fetched 100 repos from page 2 for jjn1056.
# Fetched 16 repos from page 3 for jjn1056.
# Fetching repositories for dirtycajunrice...
# Fetched 95 repos from page 1 for dirtycajunrice.
# Fetching repositories for wmorgan...
# Fetched 32 repos from page 1 for wmorgan.
# Fetching repositories for jimangel...
# Fetched 77 repos from page 1 for jimangel.
# Fetching repositories for ostris...
# Fetched 10 repos from page 1 for ostris.
# Fetching repositories for tbarn...
# Fetched 33 repos from page 1 for tbarn.
# Fetching repositories for sjenning...
# Fetched 100 repos from page 1 for sjenning.
# Fetched 11 repos from page 2 for sjenning.
# Fetching repositories for andrewsmhay...
# Fetched 62 repos from page 1 for andrewsmhay.
# Fetching repositories for okorshenko...
# Fetched 7 repos from page 1 for okorshenko.
# Fetching repositories for AriTheElk...
# Fetched 100 repos from page 1 for AriTheElk.
# Fetched 1 repos from page 2 for AriTheElk.
# Fetching repositories for MaureenHelm...
# Fetched 9 repos from page 1 for MaureenHelm.
# Fetching repositories for huumn...
# Fetched 16 repos from page 1 for huumn.
# Fetching repositories for whatthejeff...
# Fetched 80 repos from page 1 for whatthejeff.
# Fetching repositories for runZeroInc...
# Fetched 15 repos from page 1 for runZeroInc.
# Fetching repositories for andrewrynhard...
# Fetched 100 repos from page 1 for andrewrynhard.
# Fetched 13 repos from page 2 for andrewrynhard.
# Fetching repositories for brookslybrand...
# Fetched 100 repos from page 1 for brookslybrand.
# Fetched 6 repos from page 2 for brookslybrand.
# Fetching repositories for tonyelhabr...
# Fetched 95 repos from page 1 for tonyelhabr.
# Fetching repositories for skeptycal...
# Fetched 100 repos from page 1 for skeptycal.
# Fetched 100 repos from page 2 for skeptycal.
# Fetched 74 repos from page 3 for skeptycal.
# Fetching repositories for adrianhorning08...
# Fetched 77 repos from page 1 for adrianhorning08.
# Fetching repositories for sbellware...
# Fetched 4 repos from page 1 for sbellware.
# Fetching repositories for daijro...
# Fetched 19 repos from page 1 for daijro.
# Fetching repositories for jarrodmedrano...
# Fetched 100 repos from page 1 for jarrodmedrano.
# Fetched 56 repos from page 2 for jarrodmedrano.
# Fetching repositories for alisonjoseph...
# Fetched 42 repos from page 1 for alisonjoseph.
# Fetching repositories for noporpoise...
# Fetched 27 repos from page 1 for noporpoise.
# Fetching repositories for roice3...
# Fetched 10 repos from page 1 for roice3.
# Fetching repositories for Adancode...
# Fetched 100 repos from page 1 for Adancode.
# Fetched 13 repos from page 2 for Adancode.
# Fetching repositories for mdxp...
# Fetched 66 repos from page 1 for mdxp.
# Fetching repositories for JnyJny...
# Fetched 100 repos from page 1 for JnyJny.
# Fetched 15 repos from page 2 for JnyJny.
# Fetching repositories for eugeneiiim...
# Fetched 57 repos from page 1 for eugeneiiim.
# Fetching repositories for hiwonjoon...
# Fetched 59 repos from page 1 for hiwonjoon.
# Fetching repositories for saranshkataria...
# Fetched 47 repos from page 1 for saranshkataria.
# Fetching repositories for andersson...
# Fetched 26 repos from page 1 for andersson.
# Fetching repositories for crccheck...
# Fetched 100 repos from page 1 for crccheck.
# Fetched 69 repos from page 2 for crccheck.
# Fetching repositories for mauvehed...
# Fetched 59 repos from page 1 for mauvehed.
# Fetching repositories for DrChat...
# Fetched 65 repos from page 1 for DrChat.
# Fetching repositories for benschw...
# Fetched 100 repos from page 1 for benschw.
# Fetched 1 repos from page 2 for benschw.
# Fetching repositories for praveenperera...
# Fetched 100 repos from page 1 for praveenperera.
# Fetched 48 repos from page 2 for praveenperera.
# Fetching repositories for mymindstorm...
# Fetched 47 repos from page 1 for mymindstorm.
# Fetching repositories for marks...
# Fetched 100 repos from page 1 for marks.
# Fetched 100 repos from page 2 for marks.
# Fetched 4 repos from page 3 for marks.
# Fetching repositories for AndyZe...
# Fetched 77 repos from page 1 for AndyZe.
# Fetching repositories for asonix...
# Fetched 100 repos from page 1 for asonix.
# Fetched 31 repos from page 2 for asonix.
# Fetching repositories for seejamescode...
# Fetched 41 repos from page 1 for seejamescode.
# Fetching repositories for acidjazz...
# Fetched 100 repos from page 1 for acidjazz.
# Fetched 5 repos from page 2 for acidjazz.
# Fetching repositories for dfridovi...
# Fetched 19 repos from page 1 for dfridovi.
# Fetching repositories for wuputah...
# Fetched 64 repos from page 1 for wuputah.
# Fetching repositories for gnobitab...
# Fetched 15 repos from page 1 for gnobitab.
# Fetching repositories for austinheap...
# Fetched 19 repos from page 1 for austinheap.
# Fetching repositories for trentpiercy...
# Fetched 17 repos from page 1 for trentpiercy.
# Fetching repositories for jseppi...
# Fetched 37 repos from page 1 for jseppi.
# Fetching repositories for ayasin...
# Fetched 19 repos from page 1 for ayasin.
# Fetching repositories for addisonlynch...
# Fetched 47 repos from page 1 for addisonlynch.
# Fetching repositories for eriknw...
# Fetched 84 repos from page 1 for eriknw.
# Fetching repositories for Seanba...
# Fetched 20 repos from page 1 for Seanba.
# Fetching repositories for kkpatel1...
# Fetched 24 repos from page 1 for kkpatel1.
# Fetching repositories for reybos...
# Fetched 21 repos from page 1 for reybos.
# Fetching repositories for jonathanrocher...
# Fetched 27 repos from page 1 for jonathanrocher.
# Fetching repositories for BubblyOrca...
# Fetched 100 repos from page 1 for BubblyOrca.
# Fetched 17 repos from page 2 for BubblyOrca.
# Fetching repositories for shashilo...
# Fetched 13 repos from page 1 for shashilo.
# Fetching repositories for erichexter...
# Fetched 70 repos from page 1 for erichexter.
# Fetching repositories for sethbergman...
# Fetched 100 repos from page 1 for sethbergman.
# Fetched 87 repos from page 2 for sethbergman.
# Fetching repositories for cnstoll...
# Fetched 21 repos from page 1 for cnstoll.
# Fetching repositories for phillipuniverse...
# Fetched 66 repos from page 1 for phillipuniverse.
# Fetching repositories for OpenSorceress...
# Fetched 100 repos from page 1 for OpenSorceress.
# Fetched 68 repos from page 2 for OpenSorceress.
# Fetching repositories for oracle-actions...
# Fetched 6 repos from page 1 for oracle-actions.
# Fetching repositories for patrickocoffeyo...
# Fetched 47 repos from page 1 for patrickocoffeyo.
# Fetching repositories for fearphage...
# Fetched 100 repos from page 1 for fearphage.
# Fetched 100 repos from page 2 for fearphage.
# Fetched 54 repos from page 3 for fearphage.
# Fetching repositories for kc5nra...
# Fetched 62 repos from page 1 for kc5nra.
# Fetching repositories for astashov...
# Fetched 87 repos from page 1 for astashov.
# Fetching repositories for mpakus...
# Fetched 100 repos from page 1 for mpakus.
# Fetched 19 repos from page 2 for mpakus.
# Fetching repositories for dbredvick...
# Fetched 69 repos from page 1 for dbredvick.
# Fetching repositories for mutualmobile...
# Fetched 86 repos from page 1 for mutualmobile.
# Fetching repositories for ivelin...
# Fetched 55 repos from page 1 for ivelin.
# Fetching repositories for matt-landers...
# Fetched 27 repos from page 1 for matt-landers.
# Data saved to users.xlsx and repositories.xlsx

# %%
import pandas as pd

# Load the users data from the Excel file
users_df = pd.read_excel("usersall.xlsx")

# Sort users by followers in descending order
top_users = users_df.sort_values(by="followers", ascending=False).head(5)

# Extract the 'login' column and convert it to a comma-separated string
top_logins = ", ".join(top_users["login"].tolist())

# Print the result
print(f"Top 5 users in Austin by followers: {top_logins}")
# Out:
# Top 5 users in Austin by followers: getify, benawad, steveklabnik, cloudflare, jbogard
